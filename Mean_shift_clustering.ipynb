# %%
import numpy as np
import pandas as pd
from sklearn.cluster import MeanShift
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
# !pip install mpl_tools
# Out:
# Collecting mpl_tools
#   Downloading mpl_tools-0.4.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib<4.0,>=3.7 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from mpl_tools) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0,>=3.7->mpl_tools) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0,>=3.7->mpl_tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0,>=3.7->mpl_tools) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0,>=3.7->mpl_tools) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0,>=3.7->mpl_tools) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0,>=3.7->mpl_tools) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0,>=3.7->mpl_tools) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0,>=3.7->mpl_tools) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib<4.0,>=3.7->mpl_tools) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\prave\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.7->matplotlib<4.0,>=3.7->mpl_tools) (1.16.0)
# Downloading mpl_tools-0.4.0-py3-none-any.whl (18 kB)
# Installing collected packages: mpl_tools
# Successfully installed mpl_tools-0.4.0

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
cordinates = [[2,2,3], [6,7,8], [5,10,13]]
X, _ = make_blobs(n_samples = 150, centers = cordinates, cluster_std = 0.60)

# %%
data_fig = plt.figure(figsize = (10,8))
ax = data_fig.add_subplot(111, projection = '3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], marker = 'o', color = 'purple')
plt.show()

# %%
from sklearn.cluster import estimate_bandwidth
bandwidth = estimate_bandwidth(x, quantile= 0.2, n_samples = 500)

# %%
msc = MeanShift(bandwidth = bandwidth, bin_seeding = True)
msc.fit(X)
cluster_centers = msc.cluster_centers_
labels = msc.labels_
cluster_label = np.unique(labels)
n_clusters = len(cluster_label)
n_clusters
# Out:
# 3
